# %% [markdown]
# <a href="https://colab.research.google.com/github/morrison-TD/GoodReadsScrape/blob/master/GoodReads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import requests
# import csv
# from bs4 import BeautifulSoup
# import urllib 
# import json
# import os
# import requests           
# import pandas as pd

# Dependencies
#from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import datetime
import time
from pprint import pprint

# %%
#url= 'https://www.goodreads.com/review/list/10783335-t-s?shelf=read' 
url= 'https://www.goodreads.com/review/list/54669882.xml?key=oiFYvnFelfL7oTwfjJ3Bng&v=2'

# %%
book_Table =pd.read_html('https://www.goodreads.com/review/list/54669882?ref=nav_mybooks')
len(book_Table)
# Out:
# 2

# %%
book_Table[1]
# Out:
#    Unnamed: 0  cover  ...                     added                 Unnamed: 9
# 0    checkbox  cover  ...  date added  Mar 14, 2020              actions  view
# 1    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 2    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 3    checkbox  cover  ...  date added  Dec 10, 2019  actions  view (with text)
# 4    checkbox  cover  ...  date added  Dec 10, 2019              actions  view
# 5    checkbox  cover  ...  date added  Mar 21, 2019              actions  view
# 6    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 7    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 8    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 9    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 10   checkbox  cover  ...  date added  Feb 05, 2019              actions  view
# ...

# %%
df1 = book_Table[1]
df1.head()
# Out:
#   Unnamed: 0  cover  ...                     added                 Unnamed: 9
# 0   checkbox  cover  ...  date added  Mar 14, 2020              actions  view
# 1   checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 2   checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 3   checkbox  cover  ...  date added  Dec 10, 2019  actions  view (with text)
# 4   checkbox  cover  ...  date added  Dec 10, 2019              actions  view
#
# [5 rows x 10 columns]

# %%
book_Table2 = pd.read_html('https://www.goodreads.com/review/list/54669882?page=2&ref=nav_mybooks')
len(book_Table2)
book_Table2[1]
# Out:
#    Unnamed: 0  cover  ...                     added     Unnamed: 9
# 0    checkbox  cover  ...  date added  Jul 07, 2016  actions  view
# 1    checkbox  cover  ...  date added  Jul 03, 2016  actions  view
# 2    checkbox  cover  ...  date added  Jun 30, 2016  actions  view
# 3    checkbox  cover  ...  date added  Jun 26, 2016  actions  view
# 4    checkbox  cover  ...  date added  Jun 26, 2016  actions  view
# 5    checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 6    checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 7    checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 8    checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 9    checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 10   checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 11   checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# 12   checkbox  cover  ...  date added  Jun 23, 2016  actions  view
# ...

# %%
df2 = book_Table2[1]
df2.head()
# Out:
#   Unnamed: 0  cover  ...                     added     Unnamed: 9
# 0   checkbox  cover  ...  date added  Jul 07, 2016  actions  view
# 1   checkbox  cover  ...  date added  Jul 03, 2016  actions  view
# 2   checkbox  cover  ...  date added  Jun 30, 2016  actions  view
# 3   checkbox  cover  ...  date added  Jun 26, 2016  actions  view
# 4   checkbox  cover  ...  date added  Jun 26, 2016  actions  view
#
# [5 rows x 10 columns]

# %%
book_Table3 = pd.read_html('https://www.goodreads.com/review/list/54669882-tomeka-morrison?utf8=%E2%9C%93&ref=nav_mybooks&per_page=75')
book_Table3[1]
# Out:
#    Unnamed: 0  cover  ...                     added                 Unnamed: 9
# 0    checkbox  cover  ...  date added  Mar 14, 2020              actions  view
# 1    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 2    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 3    checkbox  cover  ...  date added  Dec 10, 2019  actions  view (with text)
# 4    checkbox  cover  ...  date added  Dec 10, 2019              actions  view
# 5    checkbox  cover  ...  date added  Mar 21, 2019              actions  view
# 6    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 7    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 8    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 9    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 10   checkbox  cover  ...  date added  Feb 05, 2019              actions  view
# ...

# %%
df3 = book_Table3[1]
df3.count
# Out:
# <bound method DataFrame.count of    Unnamed: 0  cover  ...                     added                 Unnamed: 9
# 0    checkbox  cover  ...  date added  Mar 14, 2020              actions  view
# 1    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 2    checkbox  cover  ...  date added  Dec 17, 2019              actions  view
# 3    checkbox  cover  ...  date added  Dec 10, 2019  actions  view (with text)
# 4    checkbox  cover  ...  date added  Dec 10, 2019              actions  view
# 5    checkbox  cover  ...  date added  Mar 21, 2019              actions  view
# 6    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 7    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 8    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# 9    checkbox  cover  ...  date added  Mar 08, 2019              actions  view
# ...

# %%
frames=[df1,df3,df3]
merged_df=pd.concat(frames)
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     object
#  1   cover       90 non-null     object
#  2   title       90 non-null     object
#  3   author      90 non-null     object
#  4   rating      90 non-null     object
#  5   rating.1    90 non-null     object
#  6   my rating   90 non-null     object
#  7   read        90 non-null     object
#  8   added       90 non-null     object
#  9   Unnamed: 9  90 non-null     object
# dtypes: object(10)
# memory usage: 7.7+ KB

# %%
merged_df.tail()
# Out:
#    Unnamed: 0  cover  ...                     added     Unnamed: 9
# 25   checkbox  cover  ...  date added  Dec 07, 2018  actions  view
# 26   checkbox  cover  ...  date added  Dec 07, 2018  actions  view
# 27   checkbox  cover  ...  date added  Dec 07, 2018  actions  view
# 28   checkbox  cover  ...  date added  May 17, 2018  actions  view
# 29   checkbox  cover  ...  date added  Jul 07, 2016  actions  view
#
# [5 rows x 10 columns]

# %%
merged_df.dtypes
# Out:
# Unnamed: 0    object
# cover         object
# title         object
# author        object
# rating        object
# rating.1      object
# my rating     object
# read          object
# added         object
# Unnamed: 9    object
# dtype: object

# %%
#dropped columns not needed
dropped_df = merged_df.drop(columns=['cover','Unnamed: 0','Unnamed: 9','added','rating.1'])
dropped_df.head()
# Out:
#                                                title  ...                              read
# 0  title You Are a Badass at Making Money: Master...  ...  date read  Apr 10, 2020  not set
# 1                           title Girl, Woman, Other  ...                date read  not set
# 2  title Heart and Hustle: What it takes to make ...  ...                date read  not set
# 3  title Children of Virtue and Vengeance  (Legac...  ...           date read  Jan 31, 2020
# 4  title The 5 Love Languages: The Secret to Love...  ...                date read  not set
#
# [5 rows x 5 columns]

# %%
#dropped 'author', convert to str
#dropped'avg rating' convert to float
#dropped 'read date' 
# dropped 'title' convert to str
dropped_df.author = dropped_df.author.str.replace("author","", regex=True).astype(str)
dropped_df.rating = dropped_df.rating.str.replace("avg rating","").astype(float)
dropped_df.read = dropped_df.read.str.replace("date read","", regex=True)
dropped_df.title = dropped_df.title.str.replace("title","", regex=True).astype(str)
dropped_df.head()
# Out:
#                                                title  ...                     read
# 0   You Are a Badass at Making Money: Master the ...  ...    Apr 10, 2020  not set
# 1                                 Girl, Woman, Other  ...                  not set
# 2   Heart and Hustle: What it takes to make it to...  ...                  not set
# 3   Children of Virtue and Vengeance  (Legacy of ...  ...             Jan 31, 2020
# 4   The 5 Love Languages: The Secret to Love That...  ...                  not set
#
# [5 rows x 5 columns]

# %%
dropped_df.read = dropped_df.read.str.replace("not set","", regex=True)
dropped_df.head()
# Out:
#                                                title  ...              read
# 0   You Are a Badass at Making Money: Master the ...  ...    Apr 10, 2020
# 1                                 Girl, Woman, Other  ...
# 2   Heart and Hustle: What it takes to make it to...  ...
# 3   Children of Virtue and Vengeance  (Legacy of ...  ...      Jan 31, 2020
# 4   The 5 Love Languages: The Secret to Love That...  ...
#
# [5 rows x 5 columns]

# %%
dropped_df.dtypes
# Out:
# title         object
# author        object
# rating       float64
# my rating     object
# read          object
# dtype: object

# %% [markdown]
# Page Two

# %% [markdown]
# Page Three

# %%
# Adding the DFs together

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-24a9216186db> in <module>()
# ----> 1 combo_df.dtypes
#
# NameError: name 'combo_df' is not defined

# %%
named_df.columns

# %%
named_df['Title']
# = renamed_df['Title'].str.decode('utf-8').replace(r'\n','',regex=True)

# %%
# renamed_df['Title'].str.decode('utf-8')
# renamed_df['Title']= renamed_df['Title'].str.decode('utf-8').replace(r'\n','',regex=True)

# header_df['Author'].str.decode('utf-8')
# header_df['Author']= header_df['Author'].str.decode('utf-8').replace(r'\n','',regex=True)

# header_df['Page_Count'].str.decode('utf-8')
# header_df['Page_Count']= header_df['Page_Count'].str.decode('utf-8').replace(r'\n','',regex=True)

# # header_df['Opinion'].str.decode('utf-8')
# # header_df['Opinion']= header_df['Opinion'].str.decode('utf-8').replace(r'\n','',regex=True)

# header_df['Date_Read'].str.decode('utf-8')
# header_df['Date_Read']= header_df['Date_Read'].str.decode('utf-8').replace(r'\n','',regex=True)

renamed_df.head()

# 
# for i in range(len(renamed_df.columns)):
#   renamed_df[renamed_df.columns[i]].str.decode('utf-8').replace(r'\n','',regex=True, inplace=True)
